# %%
from PIL import Image
import os

# %%
input_dir = "./data/raw/full/output_normalized"
output_dir = "./data/prepared"
os.makedirs(output_dir, exist_ok=True)

def pad_image(img, target_w, target_h):
    new_img = Image.new("RGB", (target_w, target_h), (255, 255, 255))
    new_img.paste(img, ((target_w - img.width) // 2, (target_h - img.height) // 2))
    return new_img

# --- อ่านไฟล์และ sort ---
files = sorted([f for f in os.listdir(input_dir) if f.endswith("_mangosteen_1.jpg")])

# Group images by index (i001, i002, ...)
groups = {}
for f in files:
    idx = f.split("_")[0]  # เช่น i001
    if idx not in groups:
        groups[idx] = {}
    if "upper" in f:
        groups[idx]["upper"] = f
    elif "under" in f:
        groups[idx]["under"] = f
    elif "side" in f:
        groups[idx]["side"] = f

# --- รวมภาพแต่ละกลุ่ม ---
for idx, imgs in sorted(groups.items()):
    if not all(k in imgs for k in ["upper", "under", "side"]):
        print(f"⚠️ Skip {idx}, missing images")
        continue

    upper = Image.open(os.path.join(input_dir, imgs["upper"]))
    under = Image.open(os.path.join(input_dir, imgs["under"]))
    side = Image.open(os.path.join(input_dir, imgs["side"]))
    side_flip = side.transpose(Image.Transpose.FLIP_LEFT_RIGHT)

    # Normalize ขนาด
    max_w = max(img.width for img in [upper, under, side, side_flip])
    max_h = max(img.height for img in [upper, under, side, side_flip])
    upper = pad_image(upper, max_w, max_h)
    under = pad_image(under, max_w, max_h)
    side = pad_image(side, max_w, max_h)
    side_flip = pad_image(side_flip, max_w, max_h)

    # รวมเป็น grid
    combined = Image.new("RGB", (max_w*2, max_h*2), (255, 255, 255))
    combined.paste(upper, (0, 0))
    combined.paste(under, (max_w, 0))
    combined.paste(side, (0, max_h))
    combined.paste(side_flip, (max_w, max_h))

    # Resize 224x224
    final_img = combined.resize((224, 224))
    output_path = os.path.join(output_dir, f"{idx}_mangosteen_grid.jpg")
    final_img.save(output_path)

    print(f"✅ Saved {output_path}")
# Out:
# ✅ Saved ./data/prepared/i001_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i002_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i003_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i004_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i005_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i006_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i007_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i008_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i009_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i010_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i011_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i012_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i013_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i014_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i015_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i016_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i017_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i018_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i019_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i020_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i021_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i022_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i023_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i024_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i025_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i026_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i027_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i028_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i029_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i030_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i031_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i032_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i033_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i034_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i035_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i036_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i037_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i038_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i039_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i040_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i041_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i042_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i043_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i044_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i045_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i046_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i047_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i048_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i049_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i050_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i051_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i052_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i053_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i054_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i055_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i056_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i057_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i058_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i059_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i060_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i061_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i062_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i063_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i064_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i065_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i066_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i067_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i068_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i069_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i070_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i071_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i072_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i073_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i074_mangosteen_grid.jpg
# ✅ Saved ./data/prepared/i075_mangosteen_grid.jpg
